# %% [markdown]
# # DATA 1 Practical 4
#                                                                                                     Simos Gerasimou
#
#
# ## A Data Journey Through The Titanic
#
# On April 15, 1912, during her maiden voyage from Southampton to New York, the widely considered “unsinkable” RMS Titanic sank after colliding with an iceberg [Wikipedia](https://en.wikipedia.org/wiki/RMS_Titanic). As it was considered “unsinkable”, the Titanic did not carry enough lifeboats for everyone onboard, resulting in the death of 1502 out of 2224 passengers and crew.
#
# **DataVision** has been commissioned by Her Majesty The Queen to investigate the conditions in which people survived and whether this was because of luck or whether some groups were more likely to survive than others. If discrimination due to gender or socio-economic class is identified, the Queen intends to use this information to change the cruise policies accordinly.
#
# #### Your tasks are to explore this dataset and generade some actionable knowledge.
#
#
# #### This Jupyter Notebook will be presented to  the House of Commons  who have limited knowledge about data science. So, your findings should be complemented by a suitable justification explaining what you observe and, when applicable, what does this observation  mean and, possibly, why it occurs.
#
# * For each question (task) a description is provided accompanied (most of the time) by two cells: one for writing the Python code and another for providing the justification. Feel free to add more cells if you feel they are needed, but keep the cells corresponding to the same question close by.
#
# #### Note: You are advised to use pandas and matplotlib throughout this practical. If you haven't already done so, complete the exercises on Pandas tutorial to become familiar with the library.
#
# **Pandas API Reference**: https://pandas.pydata.org/pandas-docs/stable/reference/index.html
# **Matplotlib API Reference**: https://matplotlib.org/3.1.1/api/index.html
#
# ***

# %% [markdown]
# ### Part 1: Reading dataset
#
# The Titanic dataset is available on the following link:
# * [Titanic dataset](https://drive.google.com/file/d/1lUSFcLr6CMvxqUZKiNmtsTGhtSUs4DTV/view?usp=sharing)
#
#
# **T1) Load the Titanic dataset using Pandas**
#
# **Note**: You have to download the dataset on your local machine and then load it onto the Jupyter Notebook

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

file = "titanic.csv"
df = pd.read_csv(file)

# %% [markdown]
# ***
#
# ### Part 2: Cleaning the dataset
#
# **T2) Print (i) the first 15 and (ii) the last 10 records of the dataframe**

# %%
# Write your answer here
# The first 10 records
df.head(15)
# or df[:10]  # same as df[0:10]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# 5                                    Moran, Mr. James    male   NaN      0
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 7                      Palsson, Master. Gosta Leonard    male   2.0      3
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 12                     Saundercock, Mr. William Henry    male  20.0      0
# 13                        Andersson, Mr. Anders Johan    male  39.0      1
# 14               Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
#
#     Parch            Ticket     Fare Cabin Embarked
# 0       0         A/5 21171   7.2500   NaN        S
# 1       0          PC 17599  71.2833   C85        C
# 2       0  STON/O2. 3101282   7.9250   NaN        S
# 3       0            113803  53.1000  C123        S
# 4       0            373450   8.0500   NaN        S
# 5       0            330877   8.4583   NaN        Q
# 6       0             17463  51.8625   E46        S
# 7       1            349909  21.0750   NaN        S
# 8       2            347742  11.1333   NaN        S
# 9       0            237736  30.0708   NaN        C
# 10      1           PP 9549  16.7000    G6        S
# 11      0            113783  26.5500  C103        S
# 12      0         A/5. 2151   8.0500   NaN        S
# 13      5            347082  31.2750   NaN        S
# 14      0            350406   7.8542   NaN        S

# %%
# Write your answer here
# The last 10 records
df.tail(10)
df[-10:]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 881    male  33.0      0      0            349257   7.8958   NaN        S
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 883    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q

# %% [markdown]
# **T3) Get general info about the dataset**

# %%
# Write your answer here
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %% [markdown]
# **T4) Explore the dataset and try to understand the meaning of each variable (column). Identify which variables are categorical and which are numerical.**
#
# **Note**: Inferring the meaning of variables 'Pclass', 'SibSp', 'Parch' could be challenging; think of what is missing from the dataset and what types of people were travelling on the Titanic. If you find it more difficult, the answer is at the end of this notebook

# %%
# Answer:
# - PassengerId     
# - Survived: did they survive the sinking
# - Pclass: Ticket class         
# - Name         
# - Sex          
# - Age        
# - SibSp: number of siblings/spouse(s {depending on polyamourous inclinations}) aboard the Titanic
# - Parch: number of parents/children aboard the Titanic
# - Ticket  
# - Fare    
# - Cabin   
# - Embarked

# %% [markdown]
# **T5) Get the shape of the dataframe**

# %%
# Write your answer here
df.shape
# Out:
# (891, 12)

# %% [markdown]
# **T6) Get the name of the columns for the dataframe**

# %%
# Write your answer here
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# **T7) Do you think the columns (variables) need to be more readable; especially, those that you might have found difficult to understand in T4**

# %%
# Write your answer here
# oookay
df.rename(index=str, columns={"Pclass": "Ticket Class", "Parch": "Parents and Children", "SibSp": "Siblings and Spouse"}, inplace=True)
# colloquially 'and', however logically 'or'  # assuming predominant apparent monogamy
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Ticket Class', 'Name', 'Sex', 'Age',
#        'Siblings and Spouse', 'Parents and Children', 'Ticket', 'Fare',
#        'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# **T8) Are there any duplicated records exist?**
#
# **Note**: A record is duplicated if all its entries are identical with another record

# %%
# Write your answer here
df.duplicated().sum()
# 0 returned, so no =)
# Out:
# 0

# %% [markdown]
# **T9) Copy the dataset so that you manipulate the copied dataset and leave the original unaffected**
#
# Note: Check the pandas documentation for help on how to copy the dataframe

# %%
# Write your answer here
df_original = df
df = df_original.copy()

# %% [markdown]
# **T10) Is there any missing data? Is this a messy or a clean dataset?**

# %%
# Write your answer here
missing_data_summary = df.isna().sum().sort_values(ascending=False)  # getting and sorting missing data in ascending order
missing_data_summary  # returnings
missing_data_percentages = (df.isna().sum())/(df.isna().count()).sort_values(ascending=False)  # calculating percentage of missing data
# df.isna().count() returns total number of records weirdly enough  # max records for every column actually ~ diffrent from df.count() btw 
missing_data_percentages
missing_data = pd.concat([missing_data_summary, missing_data_percentages], axis=1, keys=["Missing", "Percentage"])
missing_data
# Out:
#                       Missing  Percentage
# Cabin                     687    0.771044
# Age                       177    0.198653
# Embarked                    2    0.002245
# Fare                        0    0.000000
# Ticket                      0    0.000000
# Parents and Children        0    0.000000
# Siblings and Spouse         0    0.000000
# Sex                         0    0.000000
# Name                        0    0.000000
# Ticket Class                0    0.000000
# Survived                    0    0.000000
# PassengerId                 0    0.000000

# %% [markdown]
# **T11) What should we do with the variable with the highest number of missing data. Consider the amount of missing data compared to the total number of available data.**

# %%
# Write your answer here
# could just delete it lol
# oh wait we actually are
# dropping the cabin column
df_clean = df.drop(columns="Cabin")
df_clean.isna().sum().sort_values(ascending=False)
# Out:
# Age                     177
# Embarked                  2
# Fare                      0
# Ticket                    0
# Parents and Children      0
# Siblings and Spouse       0
# Sex                       0
# Name                      0
# Ticket Class              0
# Survived                  0
# PassengerId               0
# dtype: int64

# %% [markdown]
# **T12) Impute the categorical variable (just one) with the mode value**
#
# * Tip: check the fillna function in Pandas
# * Tip: categorical variables (columns) include data which may be divided into groups (e.g., gender)

# %%
# Write your answer here
df_clean["Embarked"] = df_clean["Embarked"].fillna(df_clean["Embarked"].mode()[0])
df_clean.isna().sum().sort_values(ascending=False)
# Out:
# Age                     177
# Embarked                  0
# Fare                      0
# Ticket                    0
# Parents and Children      0
# Siblings and Spouse       0
# Sex                       0
# Name                      0
# Ticket Class              0
# Survived                  0
# PassengerId               0
# dtype: int64

# %% [markdown]
# **T13) Plot the histogram of the numeric variable with missing data so as to determine the best value to fill in the missing data**

# %%
# Write your answer here
plt.subplots(figsize=(7, 6), dpi=100)
ax = sns.distplot(df_clean["Age"], kde=True, color="navy", hist=True, kde_kws={"shade": False}, hist_kws={"linewidth": 15, "alpha": 0.5})
# playing arounds
# ax = sns.distplot(df_clean["Age"], kde=False, kde_kws={"shade": True}, hist_kws={"linewidth": 152645, "alpha": 1})

ax.set_xlabel("Age", fontsize=20)  # setting label of x axis
ax.set_ylabel("pdf(Age)", fontsize=20)  # setting label of y axis
ax.grid(False)
# Out:
# c:\projects\scaleystuffs\venv\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **T14) Impute the numeric variable (just one) with an appropriate value**
#
# * Tip: what value does it make sense to impute for this variable?

# %%
# Write your answer here
df_clean["Age"] = df_clean["Age"].fillna(df_clean["Age"].median())
df_clean.isna().sum().sort_values(ascending=True)  # eyyy yay no missing values ~ not a messy database anymooore
# Out:
# PassengerId             0
# Survived                0
# Ticket Class            0
# Name                    0
# Sex                     0
# Age                     0
# Siblings and Spouse     0
# Parents and Children    0
# Ticket                  0
# Fare                    0
# Embarked                0
# dtype: int64

# %% [markdown]
# **T15) Get some descriptive statistics for the dataset**
#
# * Tip: Use Pandas

# %%
# Write your answer here
df_clean.describe()  # note, we only have descriptive statistics for numeric columns
# Out:
#        PassengerId    Survived  Ticket Class         Age  Siblings and Spouse  \
# count   891.000000  891.000000    891.000000  891.000000           891.000000
# mean    446.000000    0.383838      2.308642   29.361582             0.523008
# std     257.353842    0.486592      0.836071   13.019697             1.102743
# min       1.000000    0.000000      1.000000    0.420000             0.000000
# 25%     223.500000    0.000000      2.000000   22.000000             0.000000
# 50%     446.000000    0.000000      3.000000   28.000000             0.000000
# 75%     668.500000    1.000000      3.000000   35.000000             1.000000
# max     891.000000    1.000000      3.000000   80.000000             8.000000
#
#        Parents and Children        Fare
# count            891.000000  891.000000
# mean               0.381594   32.204208
# std                0.806057   49.693429
# min                0.000000    0.000000
# 25%                0.000000    7.910400
# 50%                0.000000   14.454200
# 75%                0.000000   31.000000
# max                6.000000  512.329200

# %% [markdown]
# **T16) Plot a density graph that shows the age distribution of passengers who survived and did not survive**
#
# * Tip: Look at histogram plots with the KDE option

# %%
# Write your answer here
plt.subplots(figsize=(7, 6), dpi=100)
survivors_ages_series = df_clean.loc[df_clean["Survived"]==True]["Age"]  # or df_clean["Age"][df_clean["Survived"] == 1
unsurvivors_ages_series = df_clean.loc[df_clean["Survived"]==False]["Age"]   # or df_clean["Age"][df_clean["Survived"] == 0
ax = sns.distplot(survivors_ages_series, color="darkturquoise", kde=True, kde_kws={"shade": True}, hist=False)
ax = sns.distplot(unsurvivors_ages_series, color="lightcoral", kde=True, kde_kws={"shade": True}, hist=False)

# these ones make seperate ones, hum
# ax = sns.displot(survivors_ages_series, color="navy")
# ax = sns.displot(unsurvivors_ages_series, color="brown")

ax.set_xlabel('Age', fontsize=15) # setting x axis label
ax.set_ylabel('pdf(Age)', fontsize=15, rotation=90) # setting y axis label

# creating key/legend
ax.legend(["Survived", "Died"])
# Out:
# c:\projects\scaleystuffs\venv\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# c:\projects\scaleystuffs\venv\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **T17) For each passenger, find out how many family members she/he has in total and store this information in the dataframe**

# %%
# Write your answer here
df_clean["Family Members"] = df_clean["Parents and Children"] + df_clean["Siblings and Spouse"]
df_clean
# Out:
#      PassengerId  Survived  Ticket Class  \
# 0              1         0             3
# 1              2         1             1
# 2              3         1             3
# 3              4         1             1
# 4              5         0             3
# ..           ...       ...           ...
# 886          887         0             2
# 887          888         1             1
# 888          889         0             3
# 889          890         1             1
# 890          891         0             3
#
#                                                   Name     Sex   Age  \
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female  28.0
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
#      Siblings and Spouse  Parents and Children            Ticket     Fare  \
# 0                      1                     0         A/5 21171   7.2500
# 1                      1                     0          PC 17599  71.2833
# 2                      0                     0  STON/O2. 3101282   7.9250
# 3                      1                     0            113803  53.1000
# 4                      0                     0            373450   8.0500
# ..                   ...                   ...               ...      ...
# 886                    0                     0            211536  13.0000
# 887                    0                     0            112053  30.0000
# 888                    1                     2        W./C. 6607  23.4500
# 889                    0                     0            111369  30.0000
# 890                    0                     0            370376   7.7500
#
#     Embarked  Family Members
# 0          S               1
# 1          C               1
# 2          S               0
# 3          S               1
# 4          S               0
# ..       ...             ...
# 886        S               0
# 887        S               0
# 888        S               3
# 889        C               0
# 890        Q               0
#
# [891 rows x 12 columns]

# %% [markdown]
# **T18): Find out who has the most family members on board**

# %%
# Write your answer here
locs_of_those_with_greatest_number_of_closest_people_onboard = np.where(df_clean["Family Members"] == max(df_clean["Family Members"]))
df_clean.iloc[greatest_number_of_closest_people_onboard]  # 7 peeps it seems, all from the wizened sage fam
# Out:
#      PassengerId  Survived  Ticket Class                               Name  \
# 159          160         0             3         Sage, Master. Thomas Henry
# 180          181         0             3       Sage, Miss. Constance Gladys
# 201          202         0             3                Sage, Mr. Frederick
# 324          325         0             3           Sage, Mr. George John Jr
# 792          793         0             3            Sage, Miss. Stella Anna
# 846          847         0             3           Sage, Mr. Douglas Bullen
# 863          864         0             3  Sage, Miss. Dorothy Edith "Dolly"
#
#         Sex   Age  Siblings and Spouse  Parents and Children    Ticket   Fare  \
# 159    male  28.0                    8                     2  CA. 2343  69.55
# 180  female  28.0                    8                     2  CA. 2343  69.55
# 201    male  28.0                    8                     2  CA. 2343  69.55
# 324    male  28.0                    8                     2  CA. 2343  69.55
# 792  female  28.0                    8                     2  CA. 2343  69.55
# 846    male  28.0                    8                     2  CA. 2343  69.55
# 863  female  28.0                    8                     2  CA. 2343  69.55
#
#     Embarked  Family Members
# 159        S              10
# 180        S              10
# 201        S              10
# 324        S              10
# 792        S              10
# 846        S              10
# 863        S              10

# %% [markdown]
# **T19) Given that Titanic stopped in three ports (C = Cherbourg, Q = Queenstown, S = Southampton) before departing from the UK, can we identify any patterns regarding the ports at which passengers embarked on the Titanic? Plot a bar plot or pie chart to illustrate this**

# %%
# Write your answer here
"""
# III got the wrong idea maybe
plt.subplots(figsize=(7, 6), dpi=100)
cherbourg_port_embarkation = df_clean.loc[df_clean["Embarked"]=="C"]
queenstown_port_embarkation = df_clean.loc[df_clean["Embarked"]=="Q"]
southampton_port_embarkation = df_clean.loc[df_clean["Embarked"]=="S"]

ax = sns.displot(data=cherbourg_port_embarkation["Age"], color="darkturquoise", kind="kde", data2=queenstown_port_embarkation["Age"])
ax = sns.displot(data=queenstown_port_embarkation["Age"], color="lightcoral", kind="kde")
ax = sns.displot(data=southampton_port_embarkation["Age"], color="brown", kind="kde")

ax.set_xlabel('Age', fontsize=15) # setting x axis label
ax.set_ylabel('pdf(Age)', fontsize=15, rotation=90) # setting y axis label

# creating key/legend
ax.legend(["C", "Q", "S"])
"""
# Out:
# '\n# III got the wrong idea maybe\nplt.subplots(figsize=(7, 6), dpi=100)\ncherbourg_port_embarkation = df_clean.loc[df_clean["Embarked"]=="C"]\nqueenstown_port_embarkation = df_clean.loc[df_clean["Embarked"]=="Q"]\nsouthampton_port_embarkation = df_clean.loc[df_clean["Embarked"]=="S"]\n\nax = sns.displot(data=cherbourg_port_embarkation["Age"], color="darkturquoise", kind="kde", data2=queenstown_port_embarkation["Age"])\nax = sns.displot(data=queenstown_port_embarkation["Age"], color="lightcoral", kind="kde")\nax = sns.displot(data=southampton_port_embarkation["Age"], color="brown", kind="kde")\n\nax.set_xlabel(\'Age\', fontsize=15) # setting x axis label\nax.set_ylabel(\'pdf(Age)\', fontsize=15, rotation=90) # setting y axis label\n\n# creating key/legend\nax.legend(["C", "Q", "S"])\n'

# %%
plt.subplots(figsize=(7,6), dpi=100)
ax = sns.countplot(data=df_clean, x="Embarked")
ax.set_xlabel("Port", fontsize=20)
ax.set_ylabel("Embarked", fontsize=20, rotation=90)
ax.grid(False)

# %% [markdown]
# **T20) Did passengers of higher socioeconomic class have a higher rate of survival? Draw a bar plot to visualise this and calculate the percentage of passengers survived from each class**
#
# * Tip: Which variable signigies a difference in socioeconomic class among passengers?

# %%
# Write your answer here
# signifies, rather
plt.subplots(figsize=(7,6), dpi=100)
ax = sns.barplot(x="Ticket Class", y="Survived", data=df_clean)
ax.set_xlabel('Ticket class', fontsize=20) # set x label
ax.set_ylabel('Survived', fontsize=20, rotation=90) # set y label
ax.grid(False)

# %%
# printing percentages of people by Ticket class that survived
first_class_survivors_percentage = df_clean["Survived"][df_clean["Ticket Class"] == 1].value_counts(normalize=True)[1]*100  # shortcuts, it seems
print("percentage of people with ticket class 1 who survived: ", first_class_survivors_percentage)
second_class_survivors_percentage = df_clean["Survived"][df_clean["Ticket Class"] == 2].value_counts(normalize=True)[1]*100
print("percentage of people with ticket class 2 who survived: ", second_class_survivors_percentage)
third_class_survivors_percentage = df_clean["Survived"][df_clean["Ticket Class"] == 3].value_counts(normalize=True)[1]*100
print("percentage of people with ticket class 3 who survived: ", third_class_survivors_percentage)
# so. gradual descent.
# Out:
# percentage of people with ticket class 1 who survived:  62.96296296296296
# percentage of people with ticket class 2 who survived:  47.28260869565217
# percentage of people with ticket class 3 who survived:  24.236252545824847

# %% [markdown]
# **T21) Following from T20, can you display the same information as a table using the groupby operator of Pandas with the ticket class as the index?**
#
# * Tip: Look at https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# * Tip: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html

# %%
# Write your answer here
df_clean[["Ticket Class", "Survived"]].groupby(["Ticket Class"], as_index=True).mean()\
.sort_values(by="Survived", ascending=False)
# note: \ is a line continuation marker
# Out:
#               Survived
# Ticket Class
# 1             0.629630
# 2             0.472826
# 3             0.242363

# %% [markdown]
# **T22) Given the interesting insights from T20 and T21, it seems interesting to see whether there is any pattern with regards to the ticket class and where passengers embarked the ship. Generate a table to display this using the crosstabs operator of Pandas with the ticket class as the index and embarkement point as the other axis**
#
# * Tip: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.crosstab.html
#
# **Note:** This is called a **contingency table** and summarises data for two (or more) categorical variables

# %%
# Write your answer here
pd.crosstab(df_clean["Ticket Class"], df_clean["Embarked"], margins="All")
# Out:
# Embarked        C   Q    S  All
# Ticket Class
# 1              85   2  129  216
# 2              17   3  164  184
# 3              66  72  353  491
# All           168  77  646  891

# %% [markdown]
# **T23) Following from T22, generate a similar contingency table but group further the horizontal axis (ticket class) with information whether/how many passengers have survived or not**
#
# * Tip: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.crosstab.html

# %%
# Write your answer here
pd.crosstab([df_clean["Ticket Class"], df_clean["Survived"]], df_clean["Embarked"], margins="All")
# Out:
# Embarked                 C   Q    S  All
# Ticket Class Survived
# 1            0          26   1   53   80
#              1          59   1   76  136
# 2            0           8   1   88   97
#              1           9   2   76   87
# 3            0          41  45  286  372
#              1          25  27   67  119
# All                    168  77  646  891

# %% [markdown]
# **T24) How was the ticket fare distributed per class? Generate a boxplot and investigate whether there are any interesting insights**

# %%
# Write your answer here
plt.subplots(figsize=(7,6), dpi=100)
ax = sns.boxplot(x="Ticket Class", y="Fare", data=df_clean)
ax.set_xlabel("Ticket Class", fontsize=20)
ax.set_ylabel("Fare", fontsize=20, rotation=90)
ax.grid(False)

# %% [markdown]
# **T25) Have you identified this fare value which is so far away from the typical fare values for first class tickets? Can you identify the ticket holder(s) and whether they survived?**

# %%
# Write your answer here
df_clean[df_clean["Fare"] == max(df_clean["Fare"])]  # hummm, all survived, it seems
# Out:
#      PassengerId  Survived  Ticket Class                                Name  \
# 258          259         1             1                    Ward, Miss. Anna
# 679          680         1             1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1             1              Lesurer, Mr. Gustave J
#
#         Sex   Age  Siblings and Spouse  Parents and Children    Ticket  \
# 258  female  35.0                    0                     0  PC 17755
# 679    male  36.0                    0                     1  PC 17755
# 737    male  35.0                    0                     0  PC 17755
#
#          Fare Embarked  Family Members
# 258  512.3292        C               0
# 679  512.3292        C               1
# 737  512.3292        C               0

# %% [markdown]
# **T26) Following from T24, can you display the same information as a table using the groupby operator of Pandas with the ticket class as the index?**
#
# Tip: Look at https://jakevdp.github.io/PythonDataScienceHandbook/03.08-aggregation-and-grouping.html
# Tip: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html**

# %%
# Write your answer here
df_clean[["Ticket Class", "Fare"]].groupby("Ticket Class", as_index=False).median().sort_values(by="Ticket Class", ascending=True)
# Out:
#    Ticket Class     Fare
# 0             1  60.2875
# 1             2  14.2500
# 2             3   8.0500

# %% [markdown]
# **T27) Implement the Pearson colleration metric to investigate whether there is any correlation between 'Fare' and 'Survived'. Do the same for the Spearman colleration metric. Once you finish the implementation you can check their correctness using the built-in functions of Scipy.stats**
#
# **What is your interpretation for the correlation between "Fare" and "Survived"?**
#
# * Tip: See https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.pearsonr.html
# * Tip: See https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.stats.spearmanr.html

# %%
# Write your answer here
import numpy as np
from scipy import stats
print(stats.pearsonr(df_clean['Survived'], df_clean['Ticket Class']))
print(stats.spearmanr(df_clean['Survived'], df_clean['Ticket Class']))
# Out:
# (-0.33848103596101503, 2.5370473879790813e-25)
# SpearmanrResult(correlation=-0.33966793665005257, pvalue=1.6876081409966057e-25)

# %% [markdown]
# ### Brain Teaser
# **Generate a new column 'Title' that includes the title of each passenger and has only the following entries:**
# * Master, Miss, Mr, Mss
#
# where
# * Miss includes also Mlle and Ms
# * Mme includes also Mrs
# * all the remaining titles become Rare

# %%
# Write your answer here
# why tho

# %% [markdown]
# **Generate a contingency table to show how the title of a passenger (x axis) is related to the male/female who survived/or not (y axis)**

# %%
# Write your answer here

# %% [markdown]
# ### Should you finish earlier/want to practice at home, you could
# * Generate plots and groupings for fare, genres, age etc
# * Any other analysis that you might could generate some useful insight.
# * Try to visualise, group and use crosstabs for the datasets from Practicals 1-3

# %%
# no thank you.
# Answers to T4
# - Pclass     Ticket class	     
# - SibSp      # of siblings/spouses aboard the Titanic
# - Parch      # of parents / children aboard the Titanic
